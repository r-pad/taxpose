# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import PIL
from mpl_toolkits.axes_grid1 import ImageGrid

# %%
# Taxpose, upright
# eval_dir = "/home/beisner/code/multi_project/taxpose/logs/ndf_evals/mug_upright_taxpose_(release)/2023-05-23_230436/10"

# MLat, upright
# eval_dir = "/home/beisner/code/multi_project/taxpose/logs/ndf_evals/mug_upright_mlat_s256/2023-05-24_104251/10"

# MLat+VN, upright
# eval_dir = "/home/beisner/code/multi_project/taxpose/logs/ndf_evals/mug_upright_mlat_s256_vnn/2023-05-23_235333/10"

# Taxpose, arbitrary
# eval_dir = "/home/beisner/code/multi_project/taxpose/logs/ndf_evals/mug_arbitrary_taxpose_(release)/2023-05-24_110143/10"

# MLat, arbitrary
# eval_dir = "/home/beisner/code/multi_project/taxpose/logs/ndf_evals/mug_arbitrary_mlat_s256/2023-05-24_112657/10"

# Mlat+VN, arbitrary
# eval_dir = "/home/beisner/code/multi_project/taxpose/logs/ndf_evals/mug_arbitrary_mlat_s256_vnn/2023-05-24_105631/10"

img_dir = os.path.join(eval_dir, "teleport_imgs")
res_file = os.path.join(eval_dir, "trial_99/success_rate_eval_implicit.npz")
results_dict = np.load(res_file)

# %%
fig = plt.figure(figsize=(32., 16.))

grid = ImageGrid(fig, 111, nrows_ncols=(5, 20), share_all=True, axes_pad=0.3)
grid[0].get_yaxis().set_ticks([])
grid[0].get_xaxis().set_ticks([])

for i, ax in enumerate(grid):
    ax.imshow(PIL.Image.open(os.path.join(img_dir, f"teleport_{i}.png")))
    ax.set_xlim(350, 550)
    ax.set_ylim(350, 150)
    
    succ = results_dict["place_success_teleport_list"][i]
    ax.set_title("success" if succ else "fail", color="blue" if succ else "red")
    
plt.show()
